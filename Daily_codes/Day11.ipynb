# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blob
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 5
#       3 import matplotlib.pyplot as plt
#       4 from sklearn.cluster import KMeans
# ----> 5 from sklearn.datasets import make_blob
#
# ImportError: cannot import name 'make_blob' from 'sklearn.datasets' (C:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\datasets\__init__.py)

# %%
df = pd.read_csv("student_clustering.csv")
df

# %%
df.head()

# %%
df.info

# %%
plt.scatter(df['cgpa'],df['iq'])
plt.show()

# %%
wcss=[]

for i in range(1,11):
    model=KMeans(n_clusters=i)
    model.fit_predict(df)
    wcss.append(model.inertia_)
wcss

# %%
plt.plot(range(1,11),wcss)
plt.show()

# %%
x=df.to_numpy() #
x

# %%
x=df.iloc[:,:].values # another way of converting into array
x

# %%
model=KMeans(n_clusters=4)
y=model.fit_predict(x)
y

# %%
df["classes"]=y
df

# %%
x[y==0,0]

# %%
x[y==0,1]

# %%
plt.scatter(x[y==0,0],x[y==0,1],color='Red',label='category 0')
plt.scatter(x[y==1,0],x[y==1,1],color='Blue',label='category 1')
plt.scatter(x[y==2,0],x[y==2,1],color='Green',label='category 2')
plt.scatter(x[y==3,0],x[y==3,1],color='pink',label='category 3')
plt.title('K-Mean of student data')
plt.xlabel('CGPA')
plt.ylabel('IQ')
plt.show()

# %%
centtroids=[(-5,5,5),(-5,5,-5),(-5,-5,5),(-2.5,2.5,5),(-3,5,4)]
cluster_std=[1,1,1,1]
X,Y=make_blobs(n_samples=200,cluster_std=cluster_std,clusters=centroids,n_features=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 centtroids=[(-5,5,5),(-5,5,-5),(-5,-5,5),(-2.5,2.5,5),(-3,5,4)]
#       2 cluster_std=[1,1,1,1]
# ----> 3 X,Y=make_blobs(n_samples=200,cluster_std=cluster_std,clusters=centroids,n_features=3)
#
# NameError: name 'make_blobs' is not defined
